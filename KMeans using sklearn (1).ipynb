# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs
make_blobs?

# %%
x,y = make_blobs(n_samples=1000, n_features=2, random_state=6, centers= 5)

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
from sklearn.cluster import KMeans

km=KMeans(n_clusters=5)
km.fit(x)
# Out:
# KMeans(n_clusters=5)

# %%
centers=km.cluster_centers_
label=km.labels_
print(centers)
# Out:
# [[-3.24573698  2.50286445]
#  [ 7.91415394 -3.3104357 ]
#  [ 0.67944338 -1.58007712]
#  [ 6.40982823 -9.23950261]
#  [-7.81614263  1.83205507]]

# %%
plt.scatter(x[:,0],x[:,1],c=label)
plt.scatter(centers[:,0],centers[:,1],color='black')
plt.show()
