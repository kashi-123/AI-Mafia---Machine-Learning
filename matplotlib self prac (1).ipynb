# %%
import matplotlib.pyplot as plt
x=[2,3,4]
y=[1,2,5]
plt.plot(x,y)

# %%
x1=[1,2,3]
y1=[4,5,6]
x2=[1,2,3]
y2=[1,2,3]
plt.plot(x1,y1,label="line 1")
plt.plot(x2,y2,label="line 2")
plt.legend()

plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.close()

# %%
left=[2,4,5,6,7]
height=[10,23,34,60,43]

l=['one','two','three','four','five']
plt.bar(left,height,tick_label=l,width=0.5,color=['black','blue','grey'])
plt.title('kashish')
plt.xlabel("mine")
plt.ylabel("youre")
plt.show()

# %%
plt.close()

# %%
ages=[1,2,3,4,5,45,5,64,344,56,89,43,11,23,56,98,33,11,44,67]

bins=10
plt.hist(ages,bins,rwidth=0.2,histtype='barstacked')
plt.show()

# %%
plt.close()

# %%
x=[2,3,4,5,6,67,8,81,23,44]
y=[56,76,3,43,12,10,9,98,67,4]
plt.scatter(x,y,label='tantrum',marker="*",color="green",s=100)
plt.show()

# %%
plt.close()

# %%
a=['eat','sleep','work','play']
slices=[3,7,10,4]
colors=['black','blue','green','maroon']
plt.pie(slices,labels=a,colors=colors,startangle=90,shadow=True,explode=(0,0,0.02,0),radius=2,autopct='%1.2f%%')
plt.show()
